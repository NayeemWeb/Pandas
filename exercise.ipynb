# %%
import pandas as pd

df = pd.read_csv('C:\\Users\\PNT\\OneDrive\\Desktop\\data\WELFake_Dataset.csv')

# %% [markdown]
# #1 Load data from a CSV file

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1               1                                                NaN
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# ...

# %%
# Check for missing values
print(df.isna())
# Out:
#        Unnamed: 0  title   text  label
# 0           False  False  False  False
# 1           False  False  False  False
# 2           False  False  False  False
# 3           False  False  False  False
# 4           False  False  False  False
# ...           ...    ...    ...    ...
# 72129       False  False  False  False
# 72130       False  False  False  False
# 72131       False  False  False  False
# 72132       False  False  False  False
# 72133       False  False  False  False
#
# [72134 rows x 4 columns]

# %% [markdown]
# #Fill missing values with a specified value

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1               1                                                  0
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# ...

# %%
# Fill missing values with a specified value
df.fillna(0, inplace=True)

# Drop rows with missing values
df.dropna(inplace=True)

# %% [markdown]
# # Drop rows with missing values

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1               1                                                  0
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# ...

# %%
# Select specific columns using column labels
selected_columns = df.loc[:, ['title', 'text']]

# Filter rows based on a condition
filtered_data = df[df['label'] > 10]

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1               1                                                  0
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# ...

# %% [markdown]
# #Data Selection and Filtering:

# %%
import pandas as pd

# Sort data by a specific column
sorted_data = df.sort_values(by='label')

# %% [markdown]
# Data Transformation (Sorting data):

# %%
import pandas as pd

# Group data by a column and calculate the sum of another column
grouped_data = df.groupby('title')['text'].sum()

# %% [markdown]
# #Data Transformation (Grouping and Aggregation):

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a line plot from a DataFrame
df.plot(x='title', y='text', kind='line')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9860\2376374118.py in <module>
#       3
#       4 # Create a line plot from a DataFrame
# ----> 5 df.plot(x='title', y='text', kind='line')
#       6 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %% [markdown]
# #Data Visualization (Line plot):

# %%
import pandas as pd

# Save the DataFrame to a CSV file
df.to_csv('output.csv', index=False)

# %% [markdown]
# #Data Storage and Export (CSV):
